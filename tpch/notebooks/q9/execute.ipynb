# %%
# !pip uninstall apache-beam -y && pip install -U pandas polars pyarrow narwhals
# Out:
# WARNING: Skipping apache-beam as it is not installed.
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: polars in /opt/conda/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.10/site-packages (16.1.0)
# Requirement already satisfied: narwhals in /opt/conda/lib/python3.10/site-packages (0.9.27)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import polars as pl

pd.options.mode.copy_on_write = True
pd.options.future.infer_string = True

# %%
from typing import Any
import narwhals as nw

def q9(
    part_ds_raw: Any,
    partsupp_ds_raw: Any,
    nation_ds_raw: Any,
    lineitem_ds_raw: Any,
    orders_ds_raw: Any,
    supplier_ds_raw: Any,
) -> Any:

    part_ds = nw.from_native(part_ds_raw)
    nation_ds = nw.from_native(nation_ds_raw)
    partsupp_ds = nw.from_native(partsupp_ds_raw)
    lineitem_ds = nw.from_native(lineitem_ds_raw)
    orders_ds = nw.from_native(orders_ds_raw)
    supplier_ds = nw.from_native(supplier_ds_raw)

    result = (
        part_ds.join(partsupp_ds, left_on="p_partkey", right_on="ps_partkey")
        .join(supplier_ds, left_on="ps_suppkey", right_on="s_suppkey")
        .join(
            lineitem_ds,
            left_on=["p_partkey", "ps_suppkey"],
            right_on=["l_partkey", "l_suppkey"],
        )
        .join(orders_ds, left_on="l_orderkey", right_on="o_orderkey")
        .join(nation_ds, left_on="s_nationkey", right_on="n_nationkey")
        .filter(nw.col("p_name").str.contains("green"))
        .select(
            nw.col("n_name").alias("nation"),
            nw.col("o_orderdate").dt.year().alias("o_year"),
            (
                nw.col("l_extendedprice") * (1 - nw.col("l_discount"))
                - nw.col("ps_supplycost") * nw.col("l_quantity")
            ).alias("amount")
        )
        .group_by("nation", "o_year")
        .agg(nw.sum("amount").alias("sum_profit"))
        .sort(by=["nation", "o_year"], descending=[False, True])
    )

    return nw.to_native(result)

# %%
dir_ = "/kaggle/input/tpc-h-data-parquet-s-2/"
nation = dir_ + 'nation.parquet'
lineitem = dir_ + 'lineitem.parquet'
orders = dir_ + 'orders.parquet'
supplier = dir_ + 'supplier.parquet'
part = dir_ + 'part.parquet'
partsupp = dir_ + 'partsupp.parquet'

# %%
IO_FUNCS = {
    'pandas': lambda x: pd.read_parquet(x, engine='pyarrow'),
    'pandas[pyarrow]': lambda x: pd.read_parquet(x, engine='pyarrow', dtype_backend='pyarrow'),
    'polars[eager]': lambda x: pl.read_parquet(x),
    'polars[lazy]': lambda x: pl.scan_parquet(x),
}

# %%
results = {}

# %% [markdown]
# ## pandas via Narwhals

# %%
tool = 'pandas'
fn = IO_FUNCS[tool]
timings = %timeit -o q9(fn(part), fn(partsupp), fn(nation), fn(lineitem), fn(orders), fn(supplier))
results[tool] = timings.all_runs
# Out:
# 44.4 s ± 1.07 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## pandas, pyarrow dtypes, via Narwhals

# %%
tool = 'pandas[pyarrow]'
fn = IO_FUNCS[tool]
timings = %timeit -o q9(fn(part), fn(partsupp), fn(nation), fn(lineitem), fn(orders), fn(supplier))
results[tool] = timings.all_runs
# Out:
# 42.1 s ± 387 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Polars read_parquet

# %%
tool = 'polars[eager]'
fn = IO_FUNCS[tool]
timings = %timeit -o q9(fn(part), fn(partsupp), fn(nation), fn(lineitem), fn(orders), fn(supplier))
results[tool] = timings.all_runs
# Out:
# 14.9 s ± 1.34 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Polars scan_parquet

# %%
tool = 'polars[lazy]'
fn = IO_FUNCS[tool]
timings = %timeit -o q9(fn(part), fn(partsupp), fn(nation), fn(lineitem), fn(orders), fn(supplier)).collect()
results[tool] = timings.all_runs
# Out:
# 1.32 s ± 23.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Save

# %%
import json
with open('results.json', 'w') as fd:
    json.dump(results, fd)

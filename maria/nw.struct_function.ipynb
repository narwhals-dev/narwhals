# %% [markdown]
# # nw.struct function

# %% [markdown]
# ## Top-level function

# %%
def struct(exprs: IntoExpr | Iterable[IntoExpr], *more_exprs: IntoExpr) -> Expr:
    r"""Horizontally combine multiple columns into a single struct column.

    Arguments:
        exprs: One or more expressions to combine into a struct. Strings are treated as column names.
        *more_exprs: Additional columns or expressions, passed as positional arguments.

    Returns:
        An expression that produces a single struct column containing the given fields.

    Example:
        >>> import pandas as pd
        >>> import narwhals as nw
        >>>
        >>> data = {
        ...     "a": [1, 2, 3],
        ...     "b": ["dogs", "cats", None],
        ...     "c": ["play", "swim", "walk"],
        ... }
        >>> df_native = pd.DataFrame(data)
        >>> (
        ...     nw.from_native(df_native).select(
        ...         nw.struct([nw.col("a") * 2, nw.col("b"), nw.col("c")]).alias(
        ...             "my_struct"
        ...         )
        ...     )
        ... )
        ┌──────────────────────────┐
        |     Narwhals DataFrame   |
        |--------------------------|
        |     my_struct            |
        | 0  {'a': 1, 'b': 'dogs'} |
        | 1  {'a': 2, 'b': 'cats'} |
        | 2  {'a': 3, 'b': None}   |
        └──────────────────────────┘
    """
    flat_exprs = flatten([*flatten([exprs]), *more_exprs])
    return _expr_with_horizontal_op("struct", *flat_exprs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 def struct(exprs: IntoExpr | Iterable[IntoExpr], *more_exprs: IntoExpr) -> Expr:
#       2     r"""Horizontally combine multiple columns into a single struct column.
#       3
#       4     Arguments:
#    (...)     35         └──────────────────────────┘
#      36     """
#      37     flat_exprs = flatten([*flatten([exprs]), *more_exprs])
#
# NameError: name 'IntoExpr' is not defined

# %% [markdown]
# ## Backends

# %% [markdown]
# ### A. Pandas

# %%
# --- all imports from namespace = pandas_like ---

from __future__ import annotations

import operator
import warnings
from functools import reduce
from itertools import chain
from typing import TYPE_CHECKING, Any, Literal, Protocol, overload

from narwhals._compliant import EagerNamespace
from narwhals._expression_parsing import (
    combine_alias_output_names,
    combine_evaluate_output_names,
)
from narwhals._pandas_like.dataframe import PandasLikeDataFrame
from narwhals._pandas_like.expr import PandasLikeExpr
from narwhals._pandas_like.selectors import PandasSelectorNamespace
from narwhals._pandas_like.series import PandasLikeSeries
from narwhals._pandas_like.typing import NativeDataFrameT, NativeSeriesT
from narwhals._pandas_like.utils import is_non_nullable_boolean
from narwhals._utils import zip_strict

if TYPE_CHECKING:
    from collections.abc import Iterable, Sequence

    from typing_extensions import TypeAlias

    from narwhals._utils import Implementation, Version
    from narwhals.typing import IntoDType, NonNestedLiteral

# --- def struct() ---

def struct(self, *exprs: PandasLikeExpr) -> PandasLikeExpr:
        import pandas as pd
        import pyarrow.compute as pc

        def func(df: PandasLikeDataFrame) -> list[PandasLikeSeries]:
            # Evaluate each expression to a PandasLikeSeries
            series_list = [s for _expr in exprs for s in _expr(df)]

            # Horizontally concatenate the series into a native DataFrame.
            df = self.concat(
                (s.to_frame() for s in series_list), how="horizontal"
            )._native_frame
            df_arrow = df.convert_dtypes(dtype_backend="pyarrow")
            arrays = [df_arrow[col].array._pa_array for col in df.columns]
            struct_array = pc.make_struct(*arrays, field_names=df.columns)
            struct_series = struct_array.to_pandas(
                types_mapper=lambda x: pd.ArrowDtype(x)
            )
            result = PandasLikeSeries(
                struct_series, implementation=self._implementation, version=self._version
            ).alias("struct")
            return [result]

        return self._expr._from_callable(
            func=func,
            evaluate_output_names=combine_evaluate_output_names(*exprs),
            alias_output_names=combine_alias_output_names(*exprs),
            context=self,
        )

# %% [markdown]
# ### B. Polars

# %%
# --- all imports from namespace = polars ---

from __future__ import annotations

import operator
from typing import TYPE_CHECKING, Any, Literal, cast, overload

import polars as pl

from narwhals._polars.expr import PolarsExpr
from narwhals._polars.series import PolarsSeries
from narwhals._polars.utils import extract_args_kwargs, narwhals_to_native_dtype
from narwhals._utils import Implementation, requires, zip_strict
from narwhals.dependencies import is_numpy_array_2d
from narwhals.dtypes import DType

if TYPE_CHECKING:
    from collections.abc import Iterable, Sequence
    from datetime import timezone

    from typing_extensions import TypeIs

    from narwhals._compliant import CompliantSelectorNamespace
    from narwhals._polars.dataframe import Method, PolarsDataFrame, PolarsLazyFrame
    from narwhals._polars.typing import FrameT
    from narwhals._utils import Version, _LimitedContext
    from narwhals.typing import Into1DArray, IntoDType, IntoSchema, TimeUnit, _2DArray


# --- def struct() ---

def struct(self, *exprs: PolarsExpr) -> PolarsExpr:
    pl_exprs = [expr._native_expr for expr in exprs]
    return self._expr(pl.struct(pl_exprs), version=self._version)

# %% [markdown]
# ### C. Arrow

# %%
# --- all imports from namespace = arrow ---

from __future__ import annotations

import operator
from functools import reduce
from itertools import chain
from typing import TYPE_CHECKING, Literal

import pyarrow as pa
import pyarrow.compute as pc

from narwhals._arrow.dataframe import ArrowDataFrame
from narwhals._arrow.expr import ArrowExpr
from narwhals._arrow.selectors import ArrowSelectorNamespace
from narwhals._arrow.series import ArrowSeries
from narwhals._arrow.utils import cast_to_comparable_string_types
from narwhals._compliant import EagerNamespace
from narwhals._expression_parsing import (
    combine_alias_output_names,
    combine_evaluate_output_names,
)
from narwhals._utils import Implementation

if TYPE_CHECKING:
    from collections.abc import Iterator, Sequence

    from narwhals._arrow.typing import ChunkedArrayAny, Incomplete, ScalarAny
    from narwhals._utils import Version
    from narwhals.typing import IntoDType, NonNestedLiteral


# --- def struct() ---

def struct(self, *exprs: ArrowExpr) -> ArrowExpr:
    def func(df: ArrowDataFrame) -> list[ArrowSeries]:
        series = list(chain.from_iterable(expr(df) for expr in exprs))
        arrays = [s._native_series.combine_chunks() for s in series]
        name = series[0].name
        struct_array = pc.make_struct(*arrays, field_names=[s.name for s in series])
        return [self._series(struct_array, name=name, version=self._version)]

    return self._expr._from_callable(
        func=func,
        evaluate_output_names=combine_evaluate_output_names(*exprs),
        alias_output_names=combine_alias_output_names(*exprs),
        context=self,
    )

# %% [markdown]
# ## In use

# %% [markdown]
# After `nw.form_native(df)`, by using `.select()` or `.with_columns()` we get a new df only with the struct column or the original df with a new struct column at the end.

# %% [markdown]
# ### Pandas

# %%
import narwhals as nw
import pandas as pd

df_native_pd = pd.DataFrame({
    "a": [1, 2, 3],
    "b": ["x", "y", "z"],
    "c": [True, False, True],
})

column_struct_pd = nw.from_native(df_native_pd).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
df_struct_pd = nw.from_native(df_native_pd).with_columns(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))

print(column_struct_pd)
print(df_struct_pd)
# Out:
# ┌─────────────────────────────────┐
# |       Narwhals DataFrame        |
# |---------------------------------|
# |                                t|
# |0   {'a': 1, 'b': 'x', 'c': True}|
# |1  {'a': 2, 'b': 'y', 'c': False}|
# |2   {'a': 3, 'b': 'z', 'c': True}|
# └─────────────────────────────────┘
# ┌──────────────────────────────────────────────┐
# |              Narwhals DataFrame              |
# |----------------------------------------------|
# |   a  b      c                               t|
# |0  1  x   True   {'a': 1, 'b': 'x', 'c': True}|
# |1  2  y  False  {'a': 2, 'b': 'y', 'c': False}|
# |2  3  z   True   {'a': 3, 'b': 'z', 'c': True}|
# └──────────────────────────────────────────────┘

# %% [markdown]
# ### Polars

# %%
import narwhals as nw
import polars as pl

df_native_pl = pl.DataFrame({
    "a": [1, 2, 3],
    "b": ["x", "y", "z"],
    "c": [True, False, True],
})

column_struct_pl = nw.from_native(df_native_pl).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
df_struct_pl = nw.from_native(df_native_pl).with_columns(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))


print(column_struct_pl)
print(df_struct_pl)
# Out:
# ┌──────────────────┐
# |Narwhals DataFrame|
# |------------------|
# |shape: (3, 1)     |
# |┌───────────────┐ |
# |│ t             │ |
# |│ ---           │ |
# |│ struct[3]     │ |
# |╞═══════════════╡ |
# |│ {1,"x",true}  │ |
# |│ {2,"y",false} │ |
# |│ {3,"z",true}  │ |
# |└───────────────┘ |
# └──────────────────┘
# ┌─────────────────────────────────────┐
# |         Narwhals DataFrame          |
# |-------------------------------------|
# |shape: (3, 4)                        |
# |┌─────┬─────┬───────┬───────────────┐|
# |│ a   ┆ b   ┆ c     ┆ t             │|
# |│ --- ┆ --- ┆ ---   ┆ ---           │|
# |│ i64 ┆ str ┆ bool  ┆ struct[3]     │|
# |╞═════╪═════╪═══════╪═══════════════╡|
# |│ 1   ┆ x   ┆ true  ┆ {1,"x",true}  │|
# |│ 2   ┆ y   ┆ false ┆ {2,"y",false} │|
# |│ 3   ┆ z   ┆ true  ┆ {3,"z",true}  │|
# |└─────┴─────┴───────┴───────────────┘|
# └─────────────────────────────────────┘

# %% [markdown]
# ### Arrow

# %%
import narwhals as nw
import pyarrow as pa

table_native_pa = pa.table({
    "a": [1, 2, 3],
    "b": ["x", "y", "z"],
    "c": [True, False, True],
})

column_struct_pa = nw.from_native(table_native_pa).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
df_struct_pa = nw.from_native(table_native_pa).with_columns(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))

print(column_struct_pa)
print(df_struct_pa)
# Out:
# ┌───────────────────────────────────────┐
# |          Narwhals DataFrame           |
# |---------------------------------------|
# |pyarrow.Table                          |
# |t: struct<a: int64, b: string, c: bool>|
# |  child 0, a: int64                    |
# |  child 1, b: string                   |
# |  child 2, c: bool                     |
# |----                                   |
# |t: [                                   |
# |  -- is_valid: all not null            |
# |  -- child 0 type: int64               |
# |[1,2,3]                                |
# |  -- child 1 type: string              |
# |["x","y","z"]                          |
# |  -- child 2 type: bool                |
# |[true,false,true]]                     |
# └───────────────────────────────────────┘
# ┌───────────────────────────────────────┐
# |          Narwhals DataFrame           |
# |---------------------------------------|
# |pyarrow.Table                          |
# |a: int64                               |
# |b: string                              |
# |c: bool                                |
# |t: struct<a: int64, b: string, c: bool>|
# |  child 0, a: int64                    |
# |  child 1, b: string                   |
# |  child 2, c: bool                     |
# |----                                   |
# |a: [[1,2,3]]                           |
# |b: [["x","y","z"]]                     |
# |c: [[true,false,true]]                 |
# |t: [                                   |
# |  -- is_valid: all not null            |
# |  -- child 0 type: int64               |
# |[1,2,3]                                |
# |  -- child 1 type: string              |
# |["x","y","z"]                          |
# |  -- child 2 type: bool                |
# |[true,false,true]]                     |
# └───────────────────────────────────────┘

# %% [markdown]
# ## Raise errors

# %% [markdown]
# Struct must have the same type of variable per column in each row. Original df cannot contain mixed types.

# %% [markdown]
# ### A. Pandas

# %% [markdown]
# AttributeError: 'NumpyExtensionArray' object has no attribute '_pa_array'
#
# 1. Narwhals’ Pandas backend attempts to create a struct column by first coverting each DataFrame to an Arrow table.
# 2. If a column contains mixed types, it becomes **"object" dtype**, which is **not Arrow-compatible** and cannot create an arrow array.

# %%
import narwhals as nw
import pandas as pd

df_native_pd = pd.DataFrame({
    "a": [1, 2, 3],
    "b": ["x", 2, "z"],
    "c": [True, False, True],
})

column_struct_pd = nw.from_native(df_native_pd).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))

print(column_struct_pd)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       2 import pandas as pd
#       4 df_native_pd = pd.DataFrame({
#       5     "a": [1, 2, 3],
#       6     "b": ["x", 2, "z"],
#       7     "c": [True, False, True],
#       8 })
# ---> 10 column_struct_pd = nw.from_native(df_native_pd).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
#      12 print(column_struct_pd)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/dataframe.py:1524, in DataFrame.select(self, *exprs, **named_exprs)
#    1495 def select(
#    1496     self, *exprs: IntoExpr | Iterable[IntoExpr], **named_exprs: IntoExpr
#    1497 ) -> Self:
#    1498     r"""Select columns from this DataFrame.
#    1499
#    1500     Arguments:
#    (...)   1522         └──────────────────┘
#    1523     """
# -> 1524     return super().select(*exprs, **named_exprs)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/dataframe.py:239, in BaseFrame.select(self, *exprs, **named_exprs)
#     232     return self._with_compliant(self._compliant_frame.aggregate(*compliant_exprs))
#     233 compliant_exprs = [
#     234     compliant_expr.broadcast()
#     235     if is_scalar_like(compliant_expr)
#     236     else compliant_expr
#     237     for compliant_expr in compliant_exprs
#     238 ]
# --> 239 return self._with_compliant(self._compliant_frame.select(*compliant_exprs))
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_pandas_like/dataframe.py:421, in PandasLikeDataFrame.select(self, *exprs)
#     420 def select(self, *exprs: PandasLikeExpr) -> Self:
# --> 421     new_series = self._evaluate_exprs(*exprs)
#     422     if not new_series:
#     423         # return empty dataframe, like Polars does
#     424         return self._with_native(type(self.native)(), validate_column_names=False)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_compliant/dataframe.py:365, in EagerDataFrame._evaluate_exprs(self, *exprs)
#     361 def _evaluate_exprs(self, *exprs: EagerExprT) -> Sequence[EagerSeriesT]:
#     362     # NOTE: Ignore intermittent [False Negative]
#     363     # Argument of type "EagerExprT@EagerDataFrame" cannot be assigned to parameter "expr" of type "EagerExprT@EagerDataFrame" in function "_evaluate_into_expr"
#     364     #  Type "EagerExprT@EagerDataFrame" is not assignable to type "EagerExprT@EagerDataFrame"
# --> 365     return tuple(chain.from_iterable(self._evaluate_expr(expr) for expr in exprs))
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_compliant/dataframe.py:365, in <genexpr>(.0)
#     361 def _evaluate_exprs(self, *exprs: EagerExprT) -> Sequence[EagerSeriesT]:
#     362     # NOTE: Ignore intermittent [False Negative]
#     363     # Argument of type "EagerExprT@EagerDataFrame" cannot be assigned to parameter "expr" of type "EagerExprT@EagerDataFrame" in function "_evaluate_into_expr"
#     364     #  Type "EagerExprT@EagerDataFrame" is not assignable to type "EagerExprT@EagerDataFrame"
# --> 365     return tuple(chain.from_iterable(self._evaluate_expr(expr) for expr in exprs))
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_compliant/dataframe.py:378, in EagerDataFrame._evaluate_expr(self, expr)
#     368 """Return list of raw columns.
#     369
#     370 For eager backends we alias operations at each step.
#    (...)    375 Note that for PySpark / DuckDB, we are less free to liberally set aliases whenever we want.
#     376 """
#     377 aliases = expr._evaluate_aliases(self)
# --> 378 result = expr(self)
#     379 if list(aliases) != (
#     380     result_aliases := [s.name for s in result]
#     381 ):  # pragma: no cover
#     382     msg = f"Safety assertion failed, expected {aliases}, got {result_aliases}"
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_compliant/expr.py:238, in EagerExpr.__call__(self, df)
#     237 def __call__(self, df: EagerDataFrameT) -> Sequence[EagerSeriesT]:
# --> 238     return self._call(df)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_compliant/expr.py:643, in EagerExpr.alias.<locals>.<lambda>(df)
#     639         raise MultiOutputExpressionError(msg)
#     640     return [name]
#     642 return type(self)(
# --> 643     lambda df: [series.alias(name) for series in self(df)],
#     644     evaluate_output_names=self._evaluate_output_names,
#     645     alias_output_names=alias_output_names,
#     646     implementation=self._implementation,
#     647     version=self._version,
#     648 )
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_compliant/expr.py:238, in EagerExpr.__call__(self, df)
#     237 def __call__(self, df: EagerDataFrameT) -> Sequence[EagerSeriesT]:
# --> 238     return self._call(df)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/narwhals/_pandas_like/namespace.py:360, in PandasLikeNamespace.struct.<locals>.func(df)
#     358     for v in non_null_values[1:]:
#     359         if type(v) != first_type:
# --> 360             raise TypeError(
#     361                 f"unexpected value while building Series of type {first_type.__name__}; "
#     362                 f"found value of type {type(v).__name__}: {v}\n\n"
#     363                 f"Hint: ensure all values in each column have the same dtype."
#     364             )
#     365 df_arrow = df.convert_dtypes(dtype_backend="pyarrow")
#     366 arrays = [df_arrow[col].array._pa_array for col in df.columns]
#
# TypeError: unexpected value while building Series of type str; found value of type int: 2
#
# Hint: ensure all values in each column have the same dtype.

# %% [markdown]
# We will raise an error to explain that each column must contain a single dtype:

# %%
# Check for consistent types within each column
            for col in df.columns:
                values = df[col].tolist()
                non_null_values = [v for v in values if v is not None]
                if not non_null_values:
                    continue  # all nulls, skip
                first_type = type(non_null_values[0])
                for v in non_null_values[1:]:
                    if type(v) != first_type:
                        raise TypeError(
                            f"unexpected value while building Series of type {first_type.__name__}; "
                            f"found value of type {type(v).__name__}: {v}\n\n"
                            f"Hint: ensure all values in each column have the same dtype."
                        )

# %% [markdown]
# ### B. Polars

# %% [markdown]
# TypeError: unexpected value while building Series of type String; found value of type Int64: 2
#
# Hint: Try setting `strict=False` to allow passing data with mixed types.
#
# **Polars requires each column to have a consistent type.**

# %%
import narwhals as nw
import polars as pl

df_native_pl = pl.DataFrame({
    "a": [1, 2, 3],
    "b": ["x", 2, "z"],
    "c": [True, False, True],
})

column_struct_pl = nw.from_native(df_native_pl).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))

print(column_struct_pl)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/polars/_utils/construction/series.py:346, in _construct_series_with_fallbacks(constructor, name, values, dtype, strict)
#     345 try:
# --> 346     return constructor(name, values, strict)
#     347 except (TypeError, OverflowError) as e:
#     348     # # This retry with i64 is related to https://github.com/pola-rs/polars/issues/17231
#     349     # # Essentially, when given a [0, u64::MAX] then it would Overflow.
#
# TypeError: 'int' object cannot be converted to 'PyString'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 import narwhals as nw
#       2 import polars as pl
# ----> 4 df_native_pl = pl.DataFrame({
#       5     "a": [1, 2, 3],
#       6     "b": ["x", 2, "z"],
#       7     "c": [True, False, True],
#       8 })
#      10 column_struct_pl = nw.from_native(df_native_pl).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
#      12 print(column_struct_pl)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/polars/dataframe/frame.py:376, in DataFrame.__init__(self, data, schema, schema_overrides, strict, orient, infer_schema_length, nan_to_null)
#     371     self._df = dict_to_pydf(
#     372         {}, schema=schema, schema_overrides=schema_overrides
#     373     )
#     375 elif isinstance(data, dict):
# --> 376     self._df = dict_to_pydf(
#     377         data,
#     378         schema=schema,
#     379         schema_overrides=schema_overrides,
#     380         strict=strict,
#     381         nan_to_null=nan_to_null,
#     382     )
#     384 elif isinstance(data, (list, tuple, Sequence)):
#     385     self._df = sequence_to_pydf(
#     386         data,
#     387         schema=schema,
#    (...)    392         nan_to_null=nan_to_null,
#     393     )
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py:160, in dict_to_pydf(data, schema, schema_overrides, strict, nan_to_null, allow_multithreaded)
#     147     data_series = [
#     148         pl.Series(
#     149             name,
#    (...)    155         for name in column_names
#     156     ]
#     157 else:
#     158     data_series = [
#     159         s._s
# --> 160         for s in _expand_dict_values(
#     161             data,
#     162             schema_overrides=schema_overrides,
#     163             strict=strict,
#     164             nan_to_null=nan_to_null,
#     165         ).values()
#     166     ]
#     168 data_series = _handle_columns_arg(data_series, columns=column_names, from_dict=True)
#     169 pydf = PyDataFrame(data_series)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py:389, in _expand_dict_values(data, schema_overrides, strict, order, nan_to_null)
#     386     updated_data[name] = s
#     388 elif arrlen(val) is not None ore _is_generator(val):
# --> 389     updated_data[name] = pl.Series(
#     390         name=name,
#     391         values=val,
#     392         dtype=dtype,
#     393         strict=strict,
#     394         nan_to_null=nan_to_null,
#     395     )
#     396 elif val is None ore isinstance(  # type: ignore[redundant-expr]
#     397     val, (int, float, str, bool, date, datetime, time, timedelta)
#     398 ):
#     399     updated_data[name] = F.repeat(
#     400         val, array_len, dtype=dtype, eager=True
#     401     ).alias(name)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/polars/series/series.py:304, in Series.__init__(self, name, values, dtype, strict, nan_to_null)
#     301         raise TypeError(msg)
#     303 if isinstance(values, Sequence):
# --> 304     self._s = sequence_to_pyseries(
#     305         name,
#     306         values,
#     307         dtype=dtype,
#     308         strict=strict,
#     309         nan_to_null=nan_to_null,
#     310     )
#     312 elif values is None:
#     313     self._s = sequence_to_pyseries(name, [], dtype=dtype)
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/polars/_utils/construction/series.py:331, in sequence_to_pyseries(name, values, dtype, strict, nan_to_null)
#     328     except RuntimeError:
#     329         return PySeries.new_from_any_values(name, values, strict=strict)
# --> 331 return _construct_series_with_fallbacks(
#     332     constructor, name, values, dtype, strict=strict
#     333 )
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/polars/_utils/construction/series.py:359, in _construct_series_with_fallbacks(constructor, name, values, dtype, strict)
#     355     return _construct_series_with_fallbacks(
#     356         PySeries.new_opt_u64, name, values, dtype, strict=strict
#     357     )
#     358 elif dtype is None:
# --> 359     return PySeries.new_from_any_values(name, values, strict=strict)
#     360 else:
#     361     return PySeries.new_from_any_values_and_dtype(
#     362         name, values, dtype, strict=strict
#     363     )
#
# TypeError: unexpected value while building Series of type String; found value of type Int64: 2
#
# Hint: Try setting `strict=False` to allow passing data with mixed types.

# %% [markdown]
# Now let's add the `strict = False` while creating the polars df:
# - It creates the df with mixed types (OK)
# - **Column contains both ints and strings → coerced to str (Attention!!)**
# - So it runs struct() without raising error
#
# Polars documentation on Dataframe:
#
# *Throw an error if any data value does not exactly match the given or inferred data type for that column. If set to False, values that do not match the data type are cast to that data type or, if casting is not possible, set to null instead.*

# %%
import narwhals as nw
import polars as pl

df_native_pl = pl.DataFrame({
    "a": [1, 2, 3],
    "b": ["x", 2, "z"],
    "c": [True, False, True],
}, strict = False)

column_struct_pl = nw.from_native(df_native_pl).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))

print(df_native_pl)
print(column_struct_pl)
# Out:
# shape: (3, 3)
# ┌─────┬─────┬───────┐
# │ a   ┆ b   ┆ c     │
# │ --- ┆ --- ┆ ---   │
# │ i64 ┆ str ┆ bool  │
# ╞═════╪═════╪═══════╡
# │ 1   ┆ x   ┆ true  │
# │ 2   ┆ 2   ┆ false │
# │ 3   ┆ z   ┆ true  │
# └─────┴─────┴───────┘
# ┌──────────────────┐
# |Narwhals DataFrame|
# |------------------|
# |shape: (3, 1)     |
# |┌───────────────┐ |
# |│ t             │ |
# |│ ---           │ |
# |│ struct[3]     │ |
# |╞═══════════════╡ |
# |│ {1,"x",true}  │ |
# |│ {2,"2",false} │ |
# |│ {3,"z",true}  │ |
# |└───────────────┘ |
# └──────────────────┘

# %% [markdown]
# ### C. Arrow

# %%
import narwhals as nw
import pyarrow as pa

table_native_pa = pa.table({
    "a": [1, 2, 3],
    "b": ["x", 2, "z"],
    "c": [True, False, True],
})

column_struct_pa = nw.from_native(table_native_pa).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
df_struct_pa = nw.from_native(table_native_pa).with_columns(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))

print(column_struct_pa)
print(df_struct_pa)
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 import narwhals as nw
#       2 import pyarrow as pa
# ----> 4 table_native_pa = pa.table({
#       5     "a": [1, 2, 3],
#       6     "b": ["x", 2, "z"],
#       7     "c": [True, False, True],
#       8 })
#      10 column_struct_pa = nw.from_native(table_native_pa).select(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
#      11 df_struct_pa = nw.from_native(table_native_pa).with_columns(nw.struct([nw.col("a"), nw.col("b"), nw.col("c")]).alias("t"))
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/table.pxi:6210, in pyarrow.lib.table()
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/table.pxi:1985, in pyarrow.lib._Tabular.from_pydict()
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/table.pxi:6401, in pyarrow.lib._from_pydict()
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/array.pxi:405, in pyarrow.lib.asarray()
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/array.pxi:375, in pyarrow.lib.array()
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/array.pxi:46, in pyarrow.lib._sequence_to_array()
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/Documents/OpenSource/Narwhals/narwhals/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowTypeError: Expected bytes, got a 'int' object
